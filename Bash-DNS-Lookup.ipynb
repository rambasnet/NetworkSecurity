# %% [markdown]
# # Bash DNS Lookup Commands
# - host, dig
# - start with ! to run bash commands

# %%
! man host
# Out:
# HOST(1)                              BIND9                             HOST(1)
#
# E
#        host - DNS lookup utility
#
# S
# e]
# V] {name} [server]
#
# N
# t is a simple utility for performing DNS lookups. It is normally
#        used to convert names to IP addresses and vice versa. When no arguments
# t prints a short summary of its command line
#        arguments and options.
#
# e is the domain name that is to be looked up. It can also be a
#        dotted-decimal IPv4 address or a colon-delimited IPv6 address, in which
# t will by default perform a reverse lookup for that address.
# r is an optional argument which is either the name or IP address
# t should query instead of the server or
# f.
#
# v option and asking
# t to make a query of type ANY.
#
# t will attempt to display the SOA
# e from all the listed authoritative name servers
#        for that zone. The list of name servers is defined by the NS records
#        that are found for the zone.
#
# s. This can be
#        used to lookup Hesiod or Chaosnet class resource records. The default
#        class is IN (Internet).
#
# v option is used.
#        The two options are equivalent. They have been provided for backwards
# d option switched on
# v enabled verbose output.
#
# t perform a zone
# e. Transfer the zone printing out the NS, PTR and
# a all records will be
#        printed.
#
# i option specifies that reverse lookups of IPv6 addresses should
#        use the IP6.INT domain as defined in RFC1886. The default is to use
#        IP6.ARPA.
#
# e for it to
#        be considered absolute. The default value is that defined using the
# f, or 1 if no ndots statement is
#        present. Names with fewer dots are interpreted as relative names and
# n
# f.
#
# R
# t will repeat a query that
# r is
#        negative or zero, the number of retries will default to 1.
#
# r option. Setting this
# t
#        makes. This should mean that the name server receiving the query will
# t to mimic the
#        behavior of a name server by making non-recursive queries and expecting
#        to receive answers to those queries that are usually referrals to other
#        name servers.
#
# T option makes it
#        use a TCP connection when querying the name server. TCP will be
#        automatically selected for queries that require it, such as zone
#        transfer (AXFR) requests.
#
# 6
# t to only use IPv6 query transport.
#
# e can be any
#        recognized query type: CNAME, NS, SOA, SIG, KEY, AXFR, etc. When no
# t automatically selects an appropriate
#        query type. By default, it looks for A, AAAA, and MX records, but if
# C option was given, queries will be made for SOA records, and if
# e is a dotted-decimal IPv4 address or colon-delimited IPv6 address,
# t will query for PTR records. If a query type of IXFR is chosen the
#        starting serial number can be specified by appending an equal followed
#        by the starting serial number (e.g. -t IXFR=12345678).
#
# w
# t is
# w
# t will effectively wait forever for a reply. The
#        time to wait for a response will be set to the number of seconds given
#        by the hardware's maximum value for an integer quantity.
#
# t to send the query to the next nameserver
#        if any server responds with a SERVFAIL response, which is the reverse
#        of normal stub resolver behavior.
#
# d,
# e.
#
# t to print the version number and exit.
#
# T
# t has been built with IDN (internationalized domain name)
# t
#        appropriately converts character encoding of domain name before sending
#        a request to DNS server or displaying a reply from the server. If you'd
#        like to turn off the IDN support for some reason, defines the
# E environment variable. The IDN support is disabled if the
# t runs.
#
# S
# f
#
# O
# d(8).
#
# T
#        Copyright © 2004, 2005, 2007-2009, 2014 Internet Systems Consortium,
#        Inc. ("ISC")
#        Copyright © 2000-2002 Internet Software Consortium.
#
# BIND9                          January 20, 2009                        HOST(1)

# %%
# !host google.com
# Out:
# google.com has address 216.58.217.46
# google.com has IPv6 address 2607:f8b0:400f:803::200e
# google.com mail is handled by 30 alt2.aspmx.l.google.com.
# google.com mail is handled by 10 aspmx.l.google.com.
# google.com mail is handled by 40 alt3.aspmx.l.google.com.
# google.com mail is handled by 20 alt1.aspmx.l.google.com.
# google.com mail is handled by 50 alt4.aspmx.l.google.com.

# %%
! host -a google.com # display all records
# Out:
# Trying "google.com"
# ;; ->>HEADER<<- opcode: QUERY, status: NOERROR, id: 20082
# ;; flags: qr rd ra; QUERY: 1, ANSWER: 2, AUTHORITY: 0, ADDITIONAL: 0
#
# ;; QUESTION SECTION:
# ;google.com.			IN	ANY
#
# ;; ANSWER SECTION:
# google.com.		5	IN	AAAA	2607:f8b0:4009:816::200e
# google.com.		5	IN	A	172.217.9.78
#
# Received 72 bytes from 192.168.231.2#53 in 2585 ms

# %%
! host -t a coloradomesa.edu # domain ip
# Out:
# coloradomesa.edu has address 10.0.3.167

# %%
! host -t mx coloradomesa.edu # domain mail server
# Out:
# coloradomesa.edu mail is handled by 10 mail.coloradomesa.edu.

# %%
! host -t ns coloradomesa.edu # nameserver
# Out:
# coloradomesa.edu name server ns1.coloradomesa.edu.
# coloradomesa.edu name server ns2.coloradomesa.edu.

# %% [markdown]
# ## reverse lookup
# - given IP, find the domain name

# %%
! host 72.166.224.167
# Out:
# 167.224.166.72.in-addr.arpa domain name pointer www.coloradomesa.edu.

# %%
! dig google.com
# Out:
# ; <<>> DiG 9.10.3-P4-Debian <<>> google.com
# ;; global options: +cmd
# ;; Got answer:
# ;; ->>HEADER<<- opcode: QUERY, status: NOERROR, id: 5267
# ;; flags: qr rd ra; QUERY: 1, ANSWER: 1, AUTHORITY: 0, ADDITIONAL: 1
#
# ;; OPT PSEUDOSECTION:
# ; EDNS: version: 0, flags:; udp: 4000
# ;; QUESTION SECTION:
# ;google.com.			IN	A
#
# ;; ANSWER SECTION:
# google.com.		229	IN	A	216.58.217.46
#
# ;; Query time: 7 msec
# ;; SERVER: 172.16.1.10#53(172.16.1.10)
# ;; WHEN: Mon Sep 18 15:44:01 MDT 2017
# ;; MSG SIZE  rcvd: 55
